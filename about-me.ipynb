# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Armando Lopo"
reason = "I am interested in AI because I believe in the possibility of a technologically advanced and efficient future that can be tangible with the help of Artificial Inteligence."
fun_fact = "Ive always had a keen understanding of technology since i was younger and hope to pursue a career in what I believe to be the leading technologies that will push society forward."

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Armando Lopo. I’m excited to learn because I am interested in AI because I believe in the possibility of a technologically advanced and efficient future that can be tangible with the help of Artificial Inteligence.. A fun fact about me is: Ive always had a keen understanding of technology since i was younger and hope to pursue a career in what I believe to be the leading technologies that will push society forward..
